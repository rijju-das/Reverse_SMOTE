# %%
pip install trial
# Out:
# ...
#   Created wheel for trial: filename=trial-0.1.0-py3-none-any.whl size=1476 sha256=2d0d134da62c6994fa867a4c673417ae715042e223c0fdc3745fa59d7c4068f8
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\0a\63\33\d138926afa505f1823163ac5d3a02965bb91b0ca6a7c10f0f9
# Successfully built trial
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import trial

# %%
trial.fib(5)
# Out:
# 0 1 1 2 3

# %%
trial.fib2(5)
# Out:
# [0, 1, 1, 2, 3]
